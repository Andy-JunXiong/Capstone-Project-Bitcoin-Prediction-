# %% [markdown]
# ## Import Data and Libraries

# %%
from Functions import normalize_data, time_series_CV_split, wrapper_feature_selector, train_and_predict, fine_tune_alpha, warn
import pandas as pd
from pandas import DataFrame
import numpy as np
from sklearn.metrics import mean_squared_error, mean_absolute_error, make_scorer
from sklearn.preprocessing import MinMaxScaler 
from time import time
from math import sqrt
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot
import plotly.offline as py
import plotly.graph_objs as go
import warnings
warnings.warn = warn
py.init_notebook_mode(connected=True)
# %matplotlib inline

# Train Set
train_data = pd.read_csv('bitcoin_train.csv')
train_data = train_data.drop(columns=['date','low','open','high','marketcap'])
print('n_features:', len(train_data.iloc[0]))
print('n_samples:', len(train_data))
train_data.head()
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>
# n_features: 36
# n_samples: 2735
#     close  volatility    volume  google_trends    gold  silver  platinum  \
# 0  0.2989    0.037022    548.33       0.019074  1388.5   30.67    1753.0
# 1  0.2990    0.030563    106.19       0.019074  1368.0   29.21    1722.0
# 2  0.2980    0.030563   1031.28       0.019074  1368.5   29.08    1731.0
# 3  0.3200    0.079137  13152.15       0.019074  1367.0   28.39    1735.0
# 4  0.3229    0.044001    512.04       0.019074  1367.0   28.39    1735.0
#
#    palladium    oil  usd_eur       ...        TXN_per_block  est_TXN_vol  \
# 0      784.0  89.39   1.3421       ...                  7.0       8950.0
# 1      754.0  90.30   1.3213       ...                  8.0       4746.0
# 2      766.0  88.37   1.3091       ...                  7.0       5052.0
# 3      754.0  88.07   1.2961       ...                  7.0       5304.0
# 4      754.0  88.07   1.2961       ...                  6.0       9216.0
#
#    cost_per_TXN  total_TXN_fees  usd_trade_vol  hash_rate  avg_block_size  \
# 0      1.714398        0.023855     789.544097   0.115112        0.002296
# 1      1.881279        0.017457      57.813954   0.121597        0.002129
# 2      2.585471        0.026185     890.419309   0.119165        0.001730
# 3      2.634545        0.023675   13047.281580   0.116733        0.001584
# 4      2.226883        0.006458    1273.388302   0.155644        0.001875
#
#     difficulty  num_unique_addr  miners_revenue
# 0  16307.42094              943       2129.2829
# 1  16307.42094             1064       2242.4850
# 2  16307.42094              950       2197.6500
# 3  16307.42094              887       2318.4000
# 4  16307.42094             1267       3099.8208
#
# [5 rows x 36 columns]

# %%
# Test Set
test_data = pd.read_csv('bitcoin_test.csv')
test_data = test_data.drop(columns=['date','low','open','high','marketcap'])
print('n_features:', len(test_data.iloc[0]))
print('n_samples:', len(test_data))
test_data.head()
# Out:
# n_features: 36
# n_samples: 92
#      close  volatility      volume  google_trends     gold  silver  platinum  \
# 0  6385.82    0.022569  4788259840             62  1250.45  16.030     851.0
# 1  6614.18    0.058242  4396930048             72  1247.80  15.980     839.0
# 2  6529.59    0.034094  4672309760             69  1251.75  15.930     838.0
# 3  6597.55    0.048633  4176689920             65  1255.65  16.045     834.0
# 4  6639.14    0.030521  4999240192             69  1255.50  15.950     845.5
#
#    palladium    oil  usd_eur       ...        TXN_per_block  est_TXN_vol  \
# 0        953  74.13   1.1658       ...          1284.148936  493208885.1
# 1        941  73.89   1.1639       ...          1062.904762  991949405.1
# 2        954  74.19   1.1665       ...          1413.432624  720058629.1
# 3        948  74.19   1.1665       ...          1868.508621  872392592.0
# 4        947  73.05   1.1709       ...          1543.194030  665699858.5
#
#    cost_per_TXN  total_TXN_fees  usd_trade_vol    hash_rate  avg_block_size  \
# 0     58.735614     140545.4062    489427084.1  35588942.30        0.987340
# 1     75.393733     106682.7087    224327884.6  37103365.37        0.705291
# 2     57.309569     150160.0866    281178824.1  37594816.26        0.987550
# 3     45.224241     185064.5374    356469308.6  30929068.69        1.113817
# 4     54.318173     142640.2951    345023639.3  35728406.94        0.935353
#
#      difficulty  num_unique_addr  miners_revenue
# 0  5.077500e+12           368307     10494418.50
# 1  5.077500e+12           341861     11673361.88
# 2  5.172890e+12           433257     11271293.25
# 3  5.363680e+12           456149      9617154.00
# 4  5.363680e+12           435401     11089706.00
#
# [5 rows x 36 columns]

# %%
# Combined train and test sets
combined_data = pd.concat([train_data[2613:], test_data], ignore_index=True) # use data from 03/2018 onwards only - best stationarity
combined_data['Price'] = combined_data['close'].shift(-1) # Dependent variable Y
print('n_features:', len(combined_data.iloc[0]))
print('n_samples:', len(combined_data))
combined_data = combined_data.iloc[:-1,1:]
combined_data.tail()
# Out:
# n_features: 37
# n_samples: 214
#      volatility        volume  google_trends     gold  silver  platinum  \
# 208    0.034161  4.726180e+09           61.0  1201.90  14.290     827.0
# 209    0.028964  4.437300e+09           59.0  1194.25  14.475     824.0
# 210    0.037517  4.606810e+09           58.0  1185.40  14.420     812.0
# 211    0.027904  5.014430e+09           58.0  1187.25  14.305     815.0
# 212    0.019986  4.363690e+09           48.0  1187.25  14.305     815.0
#
#      palladium    oil  usd_eur  usd_jpy   ...     est_TXN_vol  cost_per_TXN  \
# 208     1065.0  73.40   1.1777  0.00905   ...     503494967.4     52.112921
# 209     1059.0  72.22   1.1737  0.00904   ...     842041019.0     54.247914
# 210     1067.0  72.18   1.1707  0.00905   ...     748444892.4     46.610199
# 211     1094.0  73.16   1.1576  0.00906   ...     824319235.8     47.597177
# 212     1094.0  73.16   1.1576  0.00902   ...     913410388.9     51.317781
#
#      total_TXN_fees  usd_trade_vol    hash_rate  avg_block_size    difficulty  \
# 208     102965.2698    273203917.3  52622781.21        0.807114  7.152630e+12
# 209     130284.3136    390313648.8  60089527.19        0.768241  7.152630e+12
# 210     130238.5658    312748554.4  49422747.22        0.898005  7.152630e+12
# 211     154586.9390    283381555.4  50844984.55        0.877031  7.152630e+12
# 212     193097.0923    457654461.3  54756137.20        0.855169  7.152630e+12
#
#      num_unique_addr  miners_revenue    Price
# 208           469028     12385677.98  6495.00
# 209           490588     13676604.30  6676.75
# 210           474079     11369486.09  6644.13
# 211           481907     11836751.48  6601.96
# 212           527057     13046981.40  6625.56
#
# [5 rows x 36 columns]

# %% [markdown]
# ## Feature Selection Method

# %%
# Feature Meta Subset
subset = [34, 28, 30, 32, 1, 27, 2, 8, 25, 12, 22, 0, 17, 6, 18, 24, 9, 5, 31, 10, 19, 33, 23, 14] 

# Split train data into X (features) and Y (dependent variable)
data = combined_data.values 
Y_train = data[:-92,-1].reshape(-1,1) 
X_train = data[:-92,:-1]

# Training Validation samples size (1/4/18 - 30/6/18)
n_validation = 91

# Feature Selection
selected_features = wrapper_feature_selector(X_train,Y_train,LinearRegression(),subset)[0]   
print('Selected Features:',str(selected_features))

# %% [markdown]
# ### Training

# %%
# %%time
rmse,Y_train_test,Y_train_pred= train_and_predict(X_train[:,selected_features],Y_train,LinearRegression(),predict=False)
print('Train RMSE: {:0.2f}'.format(rmse))

# %% [markdown]
# ### Prediction

# %%
# %%time
# Test samples size (01/07/18 - 30/09/18)
n_validation = 90

# Split test data into X (features) and Y (dependent variable)
Y_test = data[:,-1].reshape(-1,1) # including train data for fitting the model
X_test = data[:,:-1]

rmse,Y_test,Y_pred= train_and_predict(X_test,Y_test,LinearRegression(),n_validation,predict=True)
print('Test RMSE: {:0.2f}'.format(rmse))
# Out:
# /Users/aurelius/anaconda3/envs/capstone/lib/python3.6/site-packages/sklearn/linear_model/base.py:509: RuntimeWarning:
#
# internal gelsd driver lwork query error, required iwork dimension not returned. This is likely the result of LAPACK bug 0038, fixed in LAPACK 3.2.2 (released July 21, 2010). Falling back to 'gelss' driver.
# Test Sample 1 - RMSE: 375.76, Selected Features: [0, 1, 2, 5, 6, 10, 11, 12, 16, 19, 20, 27, 30, 33, 34]
# Test Sample 2 - RMSE: 381.76, Selected Features: [0, 1, 2, 6, 9, 11, 13, 17, 19, 24, 26, 30, 33, 34]
# Test Sample 3 - RMSE: 404.54, Selected Features: [0, 1, 2, 3, 6, 8, 9, 11, 16, 18, 19, 26, 27, 30, 33, 34]
# Test Sample 4 - RMSE: 372.72, Selected Features: [0, 1, 2, 6, 11, 24, 26, 30, 33, 34]
# Test Sample 5 - RMSE: 425.41, Selected Features: [0, 1, 2, 3, 4, 6, 8, 9, 11, 13, 17, 18, 20, 25, 27, 30, 31, 33, 34]
# Test Sample 6 - RMSE: 361.60, Selected Features: [0, 1, 2, 5, 6, 11, 17, 23, 24, 30, 33, 34]
# Test Sample 7 - RMSE: 398.76, Selected Features: [0, 1, 2, 5, 6, 10, 11, 12, 16, 19, 20, 24, 27, 30, 33]
# Test Sample 8 - RMSE: 398.77, Selected Features: [0, 1, 2, 5, 6, 10, 11, 12, 16, 19, 20, 24, 27, 30, 33]
# Test Sample 9 - RMSE: 387.23, Selected Features: [0, 1, 2, 5, 6, 11, 16, 23, 24, 27, 30, 33]
# Test Sample 10 - RMSE: 384.08, Selected Features: [0, 1, 2, 5, 6, 11, 17, 19, 23, 24, 27, 30, 33]
# Test Sample 11 - RMSE: 355.49, Selected Features: [0, 1, 2, 3, 6, 11, 17, 20, 22, 24, 26, 29, 30, 31, 33, 34]
# Test Sample 12 - RMSE: 341.51, Selected Features: [0, 1, 2, 3, 6, 11, 17, 19, 21, 22, 24, 26, 29, 30, 33, 34]
# Test Sample 13 - RMSE: 362.37, Selected Features: [0, 1, 2, 5, 6, 10, 11, 12, 17, 19, 20, 22, 24, 26, 29, 30, 33, 34]
# Test Sample 14 - RMSE: 341.27, Selected Features: [0, 1, 2, 3, 5, 6, 9, 11, 17, 24, 26, 29, 30, 33, 34]
# Test Sample 15 - RMSE: 340.50, Selected Features: [0, 1, 2, 3, 6, 11, 17, 21, 22, 24, 26, 29, 30, 34]
# Test Sample 16 - RMSE: 352.31, Selected Features: [0, 1, 2, 3, 5, 6, 11, 16, 22, 23, 24, 26, 29, 30, 33, 34]
# Test Sample 17 - RMSE: 396.66, Selected Features: [0, 1, 2, 3, 4, 5, 10, 11, 13, 19, 21, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 18 - RMSE: 393.21, Selected Features: [0, 1, 2, 3, 4, 10, 11, 13, 16, 22, 24, 25, 26, 29, 33, 34]
# Test Sample 19 - RMSE: 392.20, Selected Features: [0, 1, 2, 5, 6, 10, 11, 13, 17, 19, 20, 21, 24, 25, 29, 32, 33, 34]
# Test Sample 20 - RMSE: 385.75, Selected Features: [0, 1, 2, 3, 4, 10, 11, 13, 16, 22, 24, 25, 26, 29, 33, 34]
# Test Sample 21 - RMSE: 382.60, Selected Features: [0, 1, 2, 3, 4, 10, 11, 13, 16, 22, 24, 25, 26, 29, 33, 34]
# Test Sample 22 - RMSE: 379.40, Selected Features: [0, 1, 2, 3, 10, 11, 17, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 23 - RMSE: 374.88, Selected Features: [0, 1, 2, 3, 5, 6, 11, 17, 19, 20, 21, 23, 24, 25, 29, 32, 33, 34]
# Test Sample 24 - RMSE: 374.09, Selected Features: [0, 1, 2, 4, 6, 10, 11, 14, 16, 18, 19, 20, 21, 23, 24, 25, 26, 29, 33, 34]
# Test Sample 25 - RMSE: 377.85, Selected Features: [0, 1, 2, 4, 6, 10, 11, 14, 16, 18, 19, 20, 21, 23, 24, 25, 26, 29, 33, 34]
# Test Sample 26 - RMSE: 373.73, Selected Features: [0, 1, 2, 3, 5, 6, 11, 17, 19, 20, 23, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 27 - RMSE: 356.50, Selected Features: [0, 1, 2, 3, 10, 11, 17, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 28 - RMSE: 376.18, Selected Features: [0, 1, 2, 3, 4, 9, 10, 11, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 29 - RMSE: 355.50, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 30 - RMSE: 357.67, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 31 - RMSE: 376.65, Selected Features: [0, 1, 2, 3, 4, 9, 10, 11, 13, 17, 18, 19, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 32 - RMSE: 353.71, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 33 - RMSE: 357.29, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 34 - RMSE: 353.93, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 35 - RMSE: 353.97, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 36 - RMSE: 354.05, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 37 - RMSE: 354.26, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 38 - RMSE: 358.98, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 39 - RMSE: 358.84, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 40 - RMSE: 352.25, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 41 - RMSE: 351.40, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 42 - RMSE: 348.81, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 43 - RMSE: 347.49, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 44 - RMSE: 347.60, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 45 - RMSE: 347.63, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 46 - RMSE: 350.50, Selected Features: [0, 1, 2, 10, 11, 19, 23, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 47 - RMSE: 347.07, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 48 - RMSE: 347.69, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 49 - RMSE: 347.96, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 50 - RMSE: 344.85, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 51 - RMSE: 342.73, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 52 - RMSE: 342.81, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 53 - RMSE: 346.95, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 54 - RMSE: 348.44, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 55 - RMSE: 350.19, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 56 - RMSE: 350.41, Selected Features: [0, 1, 2, 3, 10, 11, 17, 18, 19, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 57 - RMSE: 365.42, Selected Features: [0, 1, 2, 4, 9, 10, 11, 13, 17, 18, 19, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 58 - RMSE: 365.56, Selected Features: [0, 1, 2, 4, 9, 10, 11, 13, 17, 18, 19, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 59 - RMSE: 363.29, Selected Features: [0, 1, 2, 4, 9, 10, 11, 13, 17, 18, 19, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 60 - RMSE: 359.27, Selected Features: [0, 1, 2, 4, 10, 11, 13, 17, 18, 19, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 61 - RMSE: 359.33, Selected Features: [0, 1, 2, 4, 10, 11, 13, 17, 18, 19, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 62 - RMSE: 359.62, Selected Features: [0, 1, 2, 4, 10, 11, 13, 17, 18, 19, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 63 - RMSE: 348.36, Selected Features: [0, 1, 2, 4, 10, 11, 13, 16, 19, 22, 24, 25, 33, 34]
# Test Sample 64 - RMSE: 348.74, Selected Features: [0, 1, 2, 4, 10, 11, 13, 16, 19, 22, 24, 25, 33, 34]
# Test Sample 65 - RMSE: 358.42, Selected Features: [0, 1, 2, 4, 9, 10, 11, 13, 17, 18, 19, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 66 - RMSE: 370.95, Selected Features: [0, 1, 2, 4, 5, 10, 11, 13, 16, 17, 18, 19, 21, 24, 25, 26, 29, 31, 33, 34]
# Test Sample 67 - RMSE: 362.94, Selected Features: [0, 1, 2, 4, 10, 11, 18, 19, 23, 24, 25, 26, 29, 30, 31, 33, 34]
# Test Sample 68 - RMSE: 364.76, Selected Features: [0, 1, 2, 3, 4, 10, 11, 13, 19, 20, 21, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 69 - RMSE: 359.65, Selected Features: [0, 1, 2, 5, 8, 10, 11, 13, 18, 21, 22, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 70 - RMSE: 355.42, Selected Features: [0, 1, 2, 5, 8, 10, 11, 13, 18, 21, 22, 23, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 71 - RMSE: 354.13, Selected Features: [0, 1, 2, 5, 8, 10, 11, 13, 20, 21, 22, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 72 - RMSE: 349.44, Selected Features: [0, 1, 2, 4, 8, 10, 11, 18, 21, 22, 23, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 73 - RMSE: 349.41, Selected Features: [0, 1, 2, 4, 8, 10, 11, 18, 21, 22, 23, 24, 25, 26, 29, 32, 33, 34]
# Test Sample 74 - RMSE: 345.58, Selected Features: [0, 1, 2, 4, 8, 10, 11, 18, 22, 23, 24, 25, 29, 32, 33, 34]
# Test Sample 75 - RMSE: 356.19, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 76 - RMSE: 356.00, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 77 - RMSE: 355.39, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 78 - RMSE: 355.62, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 79 - RMSE: 355.22, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 80 - RMSE: 346.69, Selected Features: [0, 1, 2, 4, 8, 10, 11, 18, 22, 23, 24, 25, 29, 32, 33, 34]
# Test Sample 81 - RMSE: 356.83, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 82 - RMSE: 347.20, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 83 - RMSE: 345.62, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 84 - RMSE: 344.68, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 85 - RMSE: 342.47, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 86 - RMSE: 334.94, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 87 - RMSE: 331.78, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 88 - RMSE: 334.69, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 89 - RMSE: 334.43, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test Sample 90 - RMSE: 322.49, Selected Features: [0, 1, 2, 4, 7, 9, 10, 11, 14, 17, 18, 19, 23, 24, 25, 26, 29, 31, 32, 33, 34]
# Test RMSE: 396.50
# CPU times: user 49min 5s, sys: 17.9 s, total: 49min 23s
# Wall time: 1h 2min 39s

# %%
# Output prediction to csv file
output = {'Y_pred': Y_pred.reshape(-1,)}
output = DataFrame(output)
output.to_csv('LinearRegression.csv', index=False)

# %% [markdown]
# ### VISUALIZATION

# %%
trace1 = go.Scatter(
    x = np.arange(0, len(Y_pred), 1),
    y = Y_pred.reshape(-1,),
    mode = 'lines',
    name = 'Predicted labels',
    line = dict(color=('rgb(244, 146, 65)'), width=2)
)
trace2 = go.Scatter(
    x = np.arange(0, len(Y_test), 1),
    y = Y_test.reshape(-1,),
    mode = 'lines',
    name = 'True labels',
    line = dict(color=('rgb(66, 244, 155)'), width=2)
)

layout = dict(title = 'Comparison of true prices (on the test dataset) with prices our model predicted',
             xaxis = dict(title = 'Day number'), yaxis = dict(title = 'Price, USD'))
fig = dict(data=[trace1, trace2], layout=layout)
py.iplot(fig, filename='results_demonstrating0')
